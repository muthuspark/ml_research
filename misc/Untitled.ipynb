# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from skimage import data
from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.measure import label, regionprops
from skimage.morphology import closing, square
from skimage.color import label2rgb
from skimage.io import imread

image = imread('../resources/sudoku2.JPG')

print image.shape
label_image = label(image)

print label_image.shape
image_label_overlay = label2rgb(label_image)

fig, ax = plt.subplots()
ax.imshow(image_label_overlay)

# for region in regionprops(label_image):
#     # take regions with large enough areas
#     if region.area >= 100:
#         # draw rectangle around segmented coins
#         minr, minc, maxr, maxc = region.bbox
#         rect = mpatches.Rectangle((minc, minr), maxc - minc, maxr - minr,
#                                   fill=False, edgecolor='red', linewidth=2)
#         ax.add_patch(rect)

# ax.set_axis_off()
# plt.tight_layout()
plt.show()
# Out:
# (1124, 1285, 3)
# (1124, 1285, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-d35f8fc9766f> in <module>()
#      19
#      20 fig, ax = plt.subplots()
# ---> 21 ax.imshow(image_label_overlay)
#      22
#      23 # for region in regionprops(label_image):
#
# /home/wolf/.local/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /home/wolf/.local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5499                               resample=resample, **kwargs)
#    5500
# -> 5501         im.set_data(X)
#    5502         im.set_alpha(alpha)
#    5503         if im.get_clip_path() is None:
#
# /home/wolf/.local/lib/python2.7/site-packages/matplotlib/image.pyc in set_data(self, A)
#     652         if not (self._A.ndim == 2
#     653                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 654             raise TypeError("Invalid dimensions for image data")
#     655
#     656         if self._A.ndim == 3:
#
# TypeError: Invalid dimensions for image data
