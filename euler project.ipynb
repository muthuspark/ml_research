# %%
import math

# %%
import math

f_mil = 4000000
fib = 1
f1 = 1
f2 = 2
sum_ = f2
while fib < f_mil:    
    fib = f1 + f2
    f1 = f2
    f2 = fib
    if fib%2 == 0:
        print(fib)
        sum_+=fib

print("sum:",sum_)
# Out:
# 8
# 34
# 144
# 610
# 2584
# 10946
# 46368
# 196418
# 832040
# 3524578
# sum: 4613732

# %%
import math

n = 13195

prime_nums = []
def is_prime(num):
    if num <= 1:
        return False
    
    if len(prime_nums) > 0:
        for ii in prime_nums:
            if num%ii == 0:
                return False
    else:
        for i in range(2, num//2):
            if num%i == 0:
                return False
    return True
   
factors = []
def get_prime_factor(num):
    if is_prime(num):
        factors.append(num)
        return 
    
    to_check = num
    for i in range(2, num):
        if is_prime(i) and to_check%i == 0:
            to_check = int(to_check/i)
            factors.append(i)
            break
            
    get_prime_factor(to_check)  

get_prime_factor(600851475143)
print(factors)
# Out:
# [71, 839, 1471, 6857]

# %%
# reverse a string
"Hello World"[::-1]

def find_largest_pal():
    largest = 0
    for n1 in range(100, 1000):
        for n2 in range(100, 1000):
            mul = n1 * n2
            if str(mul) == str(mul)[::-1]:
                if mul > largest:
                    largest = mul
                    print(n1, n2, mul)
                

find_largest_pal()
# Out:
# 101 101 10201
# 101 111 11211
# 101 121 12221
# 101 131 13231
# 101 141 14241
# 101 151 15251
# 101 161 16261
# 101 171 17271
# 101 181 18281
# 101 191 19291
# 101 202 20402
# 101 212 21412
# 101 222 22422
# 101 232 23432
# 101 242 24442
# 101 252 25452
# 101 262 26462
# 101 272 27472
# 101 282 28482
# 101 292 29492
# 101 303 30603
# 101 313 31613
# 101 323 32623
# 101 333 33633
# 101 343 34643
# 101 353 35653
# 101 363 36663
# 101 373 37673
# 101 383 38683
# 101 393 39693
# 101 404 40804
# 101 414 41814
# 101 424 42824
# 101 434 43834
# 101 444 44844
# 101 454 45854
# 101 464 46864
# 101 474 47874
# 101 484 48884
# 101 494 49894
# 102 613 62526
# 102 618 63036
# 102 819 83538
# 102 824 84048
# 103 866 89198
# 107 877 93839
# 109 911 99299
# 121 881 106601
# 121 991 119911
# 143 847 121121
# 143 917 131131
# 143 987 141141
# 157 913 143341
# 173 957 165561
# 187 903 168861
# 187 933 174471
# 187 963 180081
# 209 909 189981
# 209 978 204402
# 222 946 210012
# 231 952 219912
# ...

# %%
# What is the smallest positive number that is evenly divisible by all of the numbers from 1 to 20?
import time

s = time.time()
for num in range(100000000, 1000000000):
    count = 0
    for i in range(1,21):
        if num%i == 0:
            count += 1
        else:
            break
            
    if count == 20:
        print(num)
        break
        
print("tt:", (time.time() - s))
# Out:
# 232792560
# tt: 145.89202880859375

# %%
sum_of_sqrs = 0
for i in range(1, 101):
    sum_of_sqrs += i**2

print(sum_of_sqrs)

square_of_sum = 0
_sum = 0
for i in range(1,101):
    _sum+=i
    
square_of_sum = _sum**2

print(square_of_sum)

print(square_of_sum - sum_of_sqrs)
# Out:
# 338350
# 25502500
# 25164150

# %%
def is_prime(n):
    """
    Assumes that n is a positive natural number
    """
    # We know 1 is not a prime number
    if n == 1:
        return False

    i = 2
    # This will loop from 2 to int(sqrt(x))
    while i*i <= n:
        # Check if i divides x without leaving a remainder
        if n % i == 0:
            # This means that n has a factor in between 2 and sqrt(n)
            # So it is not a prime number
            return False
        i += 1
    # If we did not find any factor in the above loop,
    # then n is a prime number
    return True

count = 0
num = 2
x = 10001
primes = []
while count < x:
    if is_prime(num):
        primes.append(num)
        count = count + 1
    num = num + 1
    
print(len(primes), primes[-1])
# Out:
# 10001 104743

# %%
digits = list("...")
step = 13
largest = 0
digit = None
for i in range(0, len(digits)-3):
    _pro = 1
    for j in digits[i:i+step]:
        _pro *= int(j)
        
    if _pro > largest:
        digit = digits[i:i+step]
        largest = _pro
        
print(digit, largest)
# Out:
# ['5', '5', '7', '6', '6', '8', '9', '6', '6', '4', '8', '9', '5'] 23514624000

# %%
list("3167")
# Out:
# ['3', '1', '6', '7']

# %%
import math 

for a in range(3, 1000):
    for b in range(a, 1000):
        c = math.sqrt(a**2 + b**2)
        if c.is_integer() and int(a+b+c) == 1000:
            print(a, b, int(c))
            print(a*b*c)
            break
# Out:
# 200 375 425
# 31875000.0

# %%
_sum = 0.0
for n in range(2, 2000001):
    if is_prime(n):
        _sum+=n
print(_sum)
# Out:
# 142913828922.0

# %%
import numpy as np

numbers = ["08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08","49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00","81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65","52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91","22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80","24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50","32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70","67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21","24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72","21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95","78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92","16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57","86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58","19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40","04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66","88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69","04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36","20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16","20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54","01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48"]
matrix = [[]] * len(numbers)
for index, num in enumerate(numbers):
    matrix[index] = num.split(' ')
    
matrix = np.array(matrix).astype(int)

r, c = matrix.shape
highest = 0
who = ""
for ri in range(r):
    for ci in range(c):
        try: #l to r
            sum1 = matrix[ri][ci] * matrix[ri][ci+1] * matrix[ri][ci+2] * matrix[ri][ci+3]
            if highest < sum1:
                highest = sum1
                who = str(ri) + ":" + str(ci) + ": " + "1"
        except:
            print("1",ri, ci)
            
        try: # b to up
            sum2 = matrix[ri][ci] * matrix[ri-1][ci] * matrix[ri-2][ci] * matrix[ri-3][ci]
            if highest < sum2:
                highest = sum2
                who = str(ri) + ":" + str(ci) + ": " + "2"
        except:
            print("2",ri, ci)
            
        try: # r to le
            sum3 = matrix[ri][ci] * matrix[ri][ci-1] * matrix[ri][ci-2] * matrix[ri][ci-3]
            if highest < sum3:
                highest = sum3
                who = str(ri) + ":" + str(ci) + ": " + "3"
        except:
            print("3",ri, ci)
            
        try: # t to b
            sum4 = matrix[ri][ci] * matrix[ri+1][ci] * matrix[ri+2][ci] * matrix[ri+3][ci]
            if highest < sum4:
                highest = sum4
                who = str(ri) + ":" + str(ci) + ": " + "4"
        except:
            print("4",ri, ci)
            
        try: # bo dia
            sum5 = matrix[ri][ci] * matrix[ri+1][ci+1] * matrix[ri+2][ci+2] * matrix[ri+3][ci+3]
            if highest < sum5:
                highest = sum5
                who = str(ri) + ":" + str(ci) + ": " + "5"
        except:
            print("5",ri, ci)
        
        try: # lt dia
            sum6 = matrix[ri][ci] * matrix[ri-1][ci-1] * matrix[ri-2][ci-2] * matrix[ri-3][ci-3]
            if highest < sum6:
                highest = sum6
                who = str(ri) + ":" + str(ci) + ": " + "6"
        except:
            print("6",ri, ci)
        
        try: # lt dia
            sum7 = matrix[ri][ci] * matrix[ri+1][ci-1] * matrix[ri+2][ci-2] * matrix[ri+3][ci-3]
            if highest < sum7:
                highest = sum7
                who = str(ri) + ":" + str(ci) + ": " + "7"
        except:
            print("7",ri, ci)    
                  
        try: # rt dia
            sum8 = matrix[ri][ci] * matrix[ri-1][ci+1] * matrix[ri-2][ci+2] * matrix[ri-3][ci+3]
            if highest < sum8:
                highest = sum8
                who = str(ri) + ":" + str(ci) + ": " + "8"
        except:
            print("8",ri, ci)
# Out:
# 1 0 17
# 5 0 17
# 8 0 17
# 1 0 18
# 5 0 18
# 8 0 18
# 1 0 19
# 5 0 19
# 8 0 19
# 1 1 17
# 5 1 17
# 8 1 17
# 1 1 18
# 5 1 18
# 8 1 18
# 1 1 19
# 5 1 19
# 8 1 19
# 1 2 17
# 5 2 17
# 8 2 17
# 1 2 18
# 5 2 18
# 8 2 18
# 1 2 19
# 5 2 19
# 8 2 19
# 1 3 17
# 5 3 17
# 8 3 17
# 1 3 18
# 5 3 18
# 8 3 18
# 1 3 19
# 5 3 19
# 8 3 19
# 1 4 17
# 5 4 17
# 8 4 17
# 1 4 18
# 5 4 18
# 8 4 18
# 1 4 19
# 5 4 19
# 8 4 19
# 1 5 17
# 5 5 17
# 8 5 17
# 1 5 18
# 5 5 18
# 8 5 18
# 1 5 19
# 5 5 19
# 8 5 19
# 1 6 17
# 5 6 17
# 8 6 17
# 1 6 18
# 5 6 18
# 8 6 18
# 1 6 19
# 5 6 19
# 8 6 19
# 1 7 17
# 5 7 17
# 8 7 17
# 1 7 18
# 5 7 18
# 8 7 18
# 1 7 19
# 5 7 19
# 8 7 19
# 1 8 17
# 5 8 17
# 8 8 17
# 1 8 18
# 5 8 18
# 8 8 18
# 1 8 19
# 5 8 19
# 8 8 19
# 1 9 17
# 5 9 17
# 8 9 17
# 1 9 18
# 5 9 18
# 8 9 18
# 1 9 19
# 5 9 19
# 8 9 19
# 1 10 17
# 5 10 17
# 8 10 17
# 1 10 18
# 5 10 18
# 8 10 18
# 1 10 19
# 5 10 19
# 8 10 19
# 1 11 17
# 5 11 17
# 8 11 17
# 1 11 18
# 5 11 18
# 8 11 18
# 1 11 19
# 5 11 19
# 8 11 19
# 1 12 17
# ...

# %%
highest
# Out:
# 70600674

# %%
who
# Out:
# '12:6: 7'

# %%
# print triangle numbers
divisors = []
i = 10

def divisors(n):
    count = 2  # accounts for 'n' and '1'
    i = 2
    while i ** 2 < n:
        if n % i == 0:
            count += 2
        i += 1
    if i ** 2 == n:
        count += 1
    return count

while True:
    tr_num = int(i*(i+1)/2)
    i+=1
    if divisors(tr_num) > 500:
        print(tr_num,divisors)
        break
# Out:
# 76576500 <function divisors at 0x10698fea0>

# %%
_sum = 0.0
k = "..."
for i in range(len(k)+1):
    if i>0 and i%50 == 0:
        print(i-50, i)
        _sum += int(k[i-50:i])
        
print("{:.2f}".format(_sum))
# Out:
# 0 50
# 50 100
# 100 150
# 150 200
# 200 250
# 250 300
# 300 350
# 350 400
# 400 450
# 450 500
# 500 550
# 550 600
# 600 650
# 650 700
# 700 750
# 750 800
# 800 850
# 850 900
# 900 950
# 950 1000
# 1000 1050
# 1050 1100
# 1100 1150
# 1150 1200
# 1200 1250
# 1250 1300
# 1300 1350
# 1350 1400
# 1400 1450
# 1450 1500
# 1500 1550
# 1550 1600
# 1600 1650
# 1650 1700
# 1700 1750
# 1750 1800
# 1800 1850
# 1850 1900
# 1900 1950
# 1950 2000
# 2000 2050
# 2050 2100
# 2100 2150
# 2150 2200
# 2200 2250
# 2250 2300
# 2300 2350
# 2350 2400
# 2400 2450
# 2450 2500
# 2500 2550
# 2550 2600
# 2600 2650
# 2650 2700
# 2700 2750
# 2750 2800
# 2800 2850
# 2850 2900
# 2900 2950
# 2950 3000
# 3000 3050
# 3050 3100
# 3100 3150
# 3150 3200
# 3200 3250
# 3250 3300
# 3300 3350
# 3350 3400
# 3400 3450
# 3450 3500
# 3500 3550
# 3550 3600
# 3600 3650
# 3650 3700
# 3700 3750
# 3750 3800
# 3800 3850
# 3850 3900
# 3900 3950
# 3950 4000
# 4000 4050
# 4050 4100
# 4100 4150
# 4150 4200
# 4200 4250
# 4250 4300
# ...

# %%
largest = 0
number = 0
for k in range(1000000):
    chain_length = 1
    start = k
    while start > 1:
        if start%2 == 0:
            start = int(start/2)
        else:
            start = 3*start+1
        chain_length+=1
        
    if chain_length > largest:
        largest = chain_length
        number = k

print(largest, number)
# Out:
# 525 837799

# %%
pro_u = 1.0
for k in range(21, 41):
    pro_u *= k
    
pro_l = 1.0
for k in range(2, 21):
    pro_l *= k

print(pro_u/pro_l)
# Out:
# 137846528820.0

# %%
_sum = 0
for k in "{:.0f}".format(math.pow(2,1000)):
    _sum+=int(k)

# %%
len("three hundred and forty-two")
# Out:
# 24
