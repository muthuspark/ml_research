# %%
from PIL import Image
import matplotlib.pyplot as plt
import pytesseract

img = Image.open('/Users/muthukrishnan/Downloads/Geometry-Pogorelov.jpg')

data = pytesseract.image_to_data(img, output_type='data.frame')

# %%
print(data[['left','top','text']])
# Out:
#      left   top         text
# 0       0     0          NaN
# 1     321    48          NaN
# 2     321    48          NaN
# 3     321    48          NaN
# 4     321    48     CONTENTS
# 5      47   275          NaN
# 6      47   275          NaN
# 7      47   275          NaN
# 8      47   275      Preface
# 9      47   319          NaN
# 10     47   319          NaN
# 11     47   321         Part
# 12     99   319         One.
# 13     47   340          NaN
# 14     47   340          NaN
# 15     47   342     Analytic
# 16    137   340     Geometry
# 17     48   380          NaN
# 18     48   380          NaN
# 19     48   387      Chapter
# 20    117   385           I.
# 21    192   383  Rectangular
# 22    305   383    Cartesian
# 23    395   381  Coordinates
# 24    502   381           in
# 25    532   380          the
# 26    570   380        Plane
# 27     50   517          NaN
# 28     50   517          NaN
# 29    192   517          NaN
# ..    ...   ...          ...
# 319   223  1056          NaN
# 320   223  1056        Polar
# 321   281  1056  Coordinates
# 322   222  1073          NaN
# 323   222  1073        Conic
# 324   281  1074     Sections
# 325   224  1091          NaN
# 326   224  1092    Equations
# 327   319  1091           of
# 328   347  1091        Conic
# 329   405  1092     Sections
# 330   485  1092           in
# 331   514  1091        Polar
# 332   570  1091  Coordinates
# 333   700   566          NaN
# 334   700   566          NaN
# 335   700   566          NaN
# 336   700   594       BeSSRs
# 337   701   566            &
# 338   701   718          NaN
# 339   701   718          NaN
# 340   701   718          NaN
# 341   702   887      SSskese
# 342   702   851            S
# 343   701   789           BB
# 344   701   718          Ses
# 345   703  1028          NaN
# 346   703  1028          NaN
# 347   703  1028          NaN
# 348   703  1028         SESS
#
# [349 rows x 3 columns]

# %%
plt.imshow(img)
